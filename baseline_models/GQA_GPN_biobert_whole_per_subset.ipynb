# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/dataset_sqa/dataset_0/new_test_sampled
# Out:
# test_sampled_0.csv   test_sampled_19.csv  test_sampled_28.csv  test_sampled_37.csv
# test_sampled_10.csv  test_sampled_1.csv   test_sampled_29.csv  test_sampled_38.csv
# test_sampled_11.csv  test_sampled_20.csv  test_sampled_2.csv   test_sampled_3.csv
# test_sampled_12.csv  test_sampled_21.csv  test_sampled_30.csv  test_sampled_4.csv
# test_sampled_13.csv  test_sampled_22.csv  test_sampled_31.csv  test_sampled_5.csv
# test_sampled_14.csv  test_sampled_23.csv  test_sampled_32.csv  test_sampled_6.csv
# test_sampled_15.csv  test_sampled_24.csv  test_sampled_33.csv  test_sampled_7.csv
# test_sampled_16.csv  test_sampled_25.csv  test_sampled_34.csv  test_sampled_8.csv
# test_sampled_17.csv  test_sampled_26.csv  test_sampled_35.csv  test_sampled_9.csv
# test_sampled_18.csv  test_sampled_27.csv  test_sampled_36.csv

# %%
# !pip uninstall triton
# Out:
# Found existing installation: triton 3.1.0
# Uninstalling triton-3.1.0:
#   Would remove:
#     /usr/local/bin/proton
#     /usr/local/bin/proton-viewer
#     /usr/local/lib/python3.11/dist-packages/triton-3.1.0.dist-info/*
#     /usr/local/lib/python3.11/dist-packages/triton/*
# Proceed (Y/n)? y
#   Successfully uninstalled triton-3.1.0

# %%
# !pip install --quiet git+https://github.com/songlab-cal/gpn.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.5/151.5 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 53.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 42.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.8/185.8 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.0/187.0 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 104.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 33.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 4.8 MB/s eta 0:00:00
#   Building wheel for gpn (setup.py) ... done
#   Building wheel for pandarallel (setup.py) ... done

# %%
pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Collecting transformers
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 76.9 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
# Successfully installed transformers-4.49.0

# %%
import gpn.model
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset, random_split
from transformers import BertConfig, AutoModel, AutoTokenizer, BertModel

class SequenceDataset(Dataset):
    def __init__(self, sequences, questions, labels, tokenizer, tokenizer_q):
        self.sequences = sequences
        self.questions = questions
        self.labels = labels
        self.tokenizer = tokenizer
        self.tokenizer_q = tokenizer_q

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        sequence = self.sequences[idx]
        label = self.labels[idx]
        question = self.questions[idx]
        inputs = self.tokenizer(sequence, return_tensors='pt', padding='max_length', max_length=512, truncation=True)["input_ids"]
        dna_attention_mask = inputs != self.tokenizer.pad_token_id
        dna_attention_mask = dna_attention_mask.squeeze(1)  # 去掉多余的维度，使形状变为 (256, 512)

        encoded_q = self.tokenizer_q(
            text=question,
            padding='max_length',
            max_length=16,
            truncation=True,
            return_tensors='pt',
            return_token_type_ids=True,
            return_attention_mask=True,
        )
        question = {"input_ids": encoded_q['input_ids'].squeeze(),
                    "token_type_ids": encoded_q['token_type_ids'].squeeze(),
            "attention_mask": encoded_q['attention_mask'].squeeze()}
        return inputs.squeeze(0), torch.tensor(label, dtype=torch.long), question["input_ids"], question['attention_mask'], question["token_type_ids"], dna_attention_mask

# df = pd.read_csv('modified_expanded_processed_sequences.csv')

train_dataset_path = '/content/drive/MyDrive/dataset_sqa/dataset_0/new_train_sampled.csv'
test_dataset_path = '/content/drive/MyDrive/dataset_sqa/dataset_0/new_test_sampled.csv'

df_train = pd.read_csv(train_dataset_path)
df_test = pd.read_csv(test_dataset_path)
train_seqs = df_train['ans'].tolist()
# test_seqs = df_test['ans'].tolist()
unique_answers = set(df_train['ans'].unique()).union(set(df_test['ans'].unique()))
answer_to_label = {answer: idx for idx, answer in enumerate(unique_answers)}

sequences_train = df_train['seq'].tolist()
questions_train = df_train['question'].tolist()
labels_train = [answer_to_label[str(answer)] for answer in df_train['ans'].tolist()]

# sequences_test = df_test['seq'].tolist()
# questions_test = df_test['question'].tolist()
# labels_test = [answer_to_label[answer] for answer in df_test['ans'].tolist()]

# model_name = "zhihan1996/DNABERT-2-117M"
# config = BertConfig.from_pretrained(model_name, trust_remote_code=True)
# dna_model = AutoModel.from_pretrained(model_name, config=config, trust_remote_code=True)
# tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
model_name = 'songlab/gpn-brassicales'
dna_model = AutoModel.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer_q = AutoTokenizer.from_pretrained("dmis-lab/biobert-v1.1")

dataset_train = SequenceDataset(sequences_train, questions_train, labels_train, tokenizer, tokenizer_q)
# dataset_test = SequenceDataset(sequences_test, questions_test, labels_test, tokenizer, tokenizer_q)
train_size = len(dataset_train)
# test_size = len(dataset_test)


train_loader = DataLoader(dataset_train, batch_size=256, shuffle=True)
# test_loader = DataLoader(dataset_test, batch_size=256, shuffle=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/466 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/264M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/516 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.09k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/77.0 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/462 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
import torch.nn as nn
import torch.optim as optim

# class Classifier(nn.Module):
#     def __init__(self, input_dim, hidden_dim, output_dim):
#         super(Classifier, self).__init__()
#         self.fc1 = nn.Linear(input_dim, hidden_dim)
#         self.relu = nn.ReLU()
#         self.fc2 = nn.Linear(hidden_dim, output_dim)
#         self.softmax = nn.Softmax(dim=1)

#     def forward(self, x):
#         x = self.fc1(x)
#         x = self.relu(x)
#         x = self.fc2(x)
#         return x

class Classifier(nn.Module):
    def __init__(self, model_name, num_labels):
        super(Classifier, self).__init__()
        self.base_model = dna_model

        self.qs_base_model = BertModel.from_pretrained('dmis-lab/biobert-v1.1')

        self.fc1 = nn.Linear(512, 128)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.1)

        self.qs_fc1 = nn.Linear(768, 128)
        self.qs_relu1 = nn.ReLU()
        self.qs_dropout1 = nn.Dropout(0.1)

        # Fusion layer after concatenation of seq and qs branches
        self.fc_fusion = nn.Linear(256, 128)
        self.relu_fusion = nn.ReLU()
        self.dropout_fusion = nn.Dropout(0.1)

        self.classifier = nn.Linear(128, num_labels)

    def forward(self, input_ids, question, attention_mask=None, token_type_ids=None, dna_attention_mask=None):
        with torch.no_grad():
            outputs = self.base_model(input_ids=input_ids, attention_mask=dna_attention_mask, encoder_attention_mask=dna_attention_mask)
        last_hidden_state = outputs[0]

        with torch.no_grad():
            qs_outputs = self.qs_base_model(input_ids=question, attention_mask=attention_mask, token_type_ids=token_type_ids, return_dict=True)

        seq_x = self.fc1(last_hidden_state[:, 0, :])
        seq_x = self.relu1(seq_x)
        seq_x = self.dropout1(seq_x)

        qs_x = self.qs_fc1(qs_outputs['pooler_output'])
        qs_x = self.qs_relu1(qs_x)
        qs_x = self.qs_dropout1(qs_x)

        # Fusion: concatenate the two branches' outputs
        combined_x = torch.cat((seq_x, qs_x), dim=1)

        # Pass through fusion layer
        x = self.fc_fusion(combined_x)
        x = self.relu_fusion(x)
        x = self.dropout_fusion(x)

        logits = self.classifier(x)
        return logits

output_dim = 37
model = Classifier(model_name, output_dim)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

num_epochs = 30
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

log_interval = 10

for epoch in range(num_epochs):
    model.train()
    print('begin')
    cnt = 0
    for batch_idx, (inputs, labels, question, attention_mask, token_type_ids, dna_attention_mask) in enumerate(train_loader):
        input_ids = inputs.to(device)
        labels = labels.to(device)
        question, attention_mask, token_type_ids = question.to(device), attention_mask.to(device), token_type_ids.to(device)
        dna_attention_mask = dna_attention_mask.squeeze(1)
        dna_attention_mask = dna_attention_mask.to(device)
        # print(input_ids.shape)
        # print(dna_attention_mask.shape)

        optimizer.zero_grad()

        outputs = model(input_ids, question, attention_mask, token_type_ids, dna_attention_mask)

        loss = criterion(outputs, labels.squeeze())
        # with torch.no_grad():
        #     hidden_states = model(inputs)[0]  # [batch_size, sequence_length, 768]
        #     embeddings = torch.mean(hidden_states, dim=1)
        # optimizer.zero_grad()
        # outputs = classifier(embeddings)

        # loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()
        torch.cuda.empty_cache()

        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(input_ids), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

    model.eval()
    for i in range(0, 39):
        dataset_name_t = f'/content/drive/MyDrive/dataset_sqa/dataset_0/new_test_sampled/test_sampled_{i}.csv'
        # dataset_test_t = GenomicBenchmarkDataset(
        #     max_length = max_length,
        #     d_output = 37,
        #     use_padding = use_padding,
        #     tokenizer_q = tokenizer_q,
        #     tokenizer=tokenizer,
        #     dataset_name=dataset_name_t,
        #     rc_aug=rc_aug,
        #     add_eos=add_eos,
        #     answer_to_label=answer_to_label
        # )
        sub_df_test = pd.read_csv(dataset_name_t)
        sub_test_seqs = sub_df_test['ans'].tolist()
        sub_sequences_test = sub_df_test['seq'].tolist()
        sub_questions_test = sub_df_test['question'].tolist()
        sub_labels_test = [answer_to_label[str(answer)] for answer in sub_df_test['ans'].tolist()]
        sub_dataset_test = SequenceDataset(sub_sequences_test, sub_questions_test, sub_labels_test, tokenizer, tokenizer_q)
        sub_test_size = len(sub_dataset_test)
        test_loader = DataLoader(sub_dataset_test, batch_size=256, shuffle=False)
        # t_loader = DataLoader(dataset_test_t, batch_size=batch_size, shuffle=False)
        print(i)
        # test(model, device, t_loader, loss_fn)
        test_loss = 0
        correct = 0
        with torch.no_grad():
            for (inputs, labels, question, attention_mask, token_type_ids, dna_attention_mask) in test_loader:
                input_ids = inputs.to(device)
                labels = labels.to(device)
                question, attention_mask, token_type_ids = question.to(device), attention_mask.to(device), token_type_ids.to(device)
                dna_attention_mask = dna_attention_mask.squeeze(1)
                dna_attention_mask = dna_attention_mask.to(device)
                outputs = model(input_ids, question, attention_mask, token_type_ids, dna_attention_mask)
                test_loss += criterion(outputs, labels.squeeze()).item()  # sum up batch loss
                pred = outputs.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                correct += pred.eq(labels.view_as(pred)).sum().item()

        test_loss /= len(test_loader.dataset)

        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)))
    #     for inputs, labels in test_loader:

    #         hidden_states = model(inputs)[0]
    #         embeddings = torch.mean(hidden_states, dim=1)
    #         outputs = classifier(embeddings)

    #         _, predicted = torch.max(outputs.data, 1)
    #         total += labels.size(0)
    #         correct += (predicted == labels).sum().item()

    # print(f'Accuracy: {100 * correct / total:.2f}%')
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
#
# 17
#
# Test set: Average loss: 0.0040, Accuracy: 482/1000 (48.20%)
#
# 18
#
# Test set: Average loss: 0.0039, Accuracy: 463/1000 (46.30%)
#
# 19
#
# Test set: Average loss: 0.0094, Accuracy: 185/999 (18.52%)
#
# 20
#
# Test set: Average loss: 0.0034, Accuracy: 448/1000 (44.80%)
#
# 21
#
# Test set: Average loss: 0.0150, Accuracy: 10/900 (1.11%)
#
# 22
#
# Test set: Average loss: 0.0050, Accuracy: 154/312 (49.36%)
#
# 23
#
# Test set: Average loss: 0.0038, Accuracy: 295/608 (48.52%)
#
# 24
#
# Test set: Average loss: 0.0037, Accuracy: 279/608 (45.89%)
#
# 25
#
# Test set: Average loss: 0.0028, Accuracy: 605/1000 (60.50%)
#
# 26
#
# Test set: Average loss: 0.0026, Accuracy: 709/1000 (70.90%)
#
# 27
#
# Test set: Average loss: 0.0086, Accuracy: 366/1000 (36.60%)
#
# 28
#
# Test set: Average loss: 0.0030, Accuracy: 587/1000 (58.70%)
#
# 29
#
# Test set: Average loss: 0.0031, Accuracy: 404/1000 (40.40%)
#
# 30
#
# Test set: Average loss: 0.0047, Accuracy: 466/999 (46.65%)
#
# 31
#
# Test set: Average loss: 0.0108, Accuracy: 149/1000 (14.90%)
#
# 32
#
# Test set: Average loss: 0.0027, Accuracy: 749/1000 (74.90%)
#
# 33
#
# Test set: Average loss: 0.0030, Accuracy: 678/1000 (67.80%)
#
# 34
#
# Test set: Average loss: 0.0031, Accuracy: 647/1000 (64.70%)
#
# 35
#
# Test set: Average loss: 0.0090, Accuracy: 225/1000 (22.50%)
#
# 36
#
# Test set: Average loss: 0.0068, Accuracy: 450/1000 (45.00%)
#
# 37
#
# Test set: Average loss: 0.0029, Accuracy: 599/1000 (59.90%)
#
# 38
#
# Test set: Average loss: 0.0033, Accuracy: 560/1000 (56.00%)
#
# begin
# Train Epoch: 8 [0/149557 (0%)]	Loss: 1.309944
# Train Epoch: 8 [2560/149557 (2%)]	Loss: 1.136495
# Train Epoch: 8 [5120/149557 (3%)]	Loss: 1.263813
# Train Epoch: 8 [7680/149557 (5%)]	Loss: 1.237723
# Train Epoch: 8 [10240/149557 (7%)]	Loss: 1.268184
# Train Epoch: 8 [12800/149557 (9%)]	Loss: 1.292662
# Train Epoch: 8 [15360/149557 (10%)]	Loss: 1.265114
# Train Epoch: 8 [17920/149557 (12%)]	Loss: 1.204860
# Train Epoch: 8 [20480/149557 (14%)]	Loss: 1.221981
# Train Epoch: 8 [23040/149557 (15%)]	Loss: 1.200108
# Train Epoch: 8 [25600/149557 (17%)]	Loss: 1.281386
# Train Epoch: 8 [28160/149557 (19%)]	Loss: 1.345897
# Train Epoch: 8 [30720/149557 (21%)]	Loss: 1.159183
# Train Epoch: 8 [33280/149557 (22%)]	Loss: 1.266329
# Train Epoch: 8 [35840/149557 (24%)]	Loss: 1.212372
# Train Epoch: 8 [38400/149557 (26%)]	Loss: 1.255238
# Train Epoch: 8 [40960/149557 (27%)]	Loss: 1.266829
# Train Epoch: 8 [43520/149557 (29%)]	Loss: 1.429853
# Test set: Average loss: 0.0028, Accuracy: 535/1000 (53.50%)
#
# 4
#
# Test set: Average loss: 0.0031, Accuracy: 536/1000 (53.60%)
#
# 5
#
# Test set: Average loss: 0.0031, Accuracy: 625/1000 (62.50%)
#
# 6
#
# Test set: Average loss: 0.0032, Accuracy: 507/1000 (50.70%)
#
# 7
#
# Test set: Average loss: 0.0123, Accuracy: 102/999 (10.21%)
#
# 8
#
# Test set: Average loss: 0.0031, Accuracy: 477/1000 (47.70%)
#
# 9
#
# Test set: Average loss: 0.0027, Accuracy: 649/1000 (64.90%)
#
# 10
#
# Test set: Average loss: 0.0030, Accuracy: 441/1000 (44.10%)
#
# 11
#
# Test set: Average loss: 0.0026, Accuracy: 630/1000 (63.00%)
#
# 12
#
# Test set: Average loss: 0.0025, Accuracy: 769/1000 (76.90%)
#
# 13
#
# Test set: Average loss: 0.0030, Accuracy: 634/1000 (63.40%)
#
# 14
#
# Test set: Average loss: 0.0025, Accuracy: 731/1000 (73.10%)
#
# 15
#
# Test set: Average loss: 0.0078, Accuracy: 406/1000 (40.60%)
#
# 16
#
# Test set: Average loss: 0.0073, Accuracy: 453/1000 (45.30%)
#
# 17
#
# Test set: Average loss: 0.0045, Accuracy: 464/1000 (46.40%)
#
# 18
#
# Test set: Average loss: 0.0043, Accuracy: 466/1000 (46.60%)
#
# 19
#
# Test set: Average loss: 0.0082, Accuracy: 243/999 (24.32%)
#
# 20
#
# Test set: Average loss: 0.0038, Accuracy: 444/1000 (44.40%)
#
# 21
#
# Test set: Average loss: 0.0141, Accuracy: 23/900 (2.56%)
#
# 22
#
# Test set: Average loss: 0.0049, Accuracy: 158/312 (50.64%)
#
# 23
#
# Test set: Average loss: 0.0039, Accuracy: 301/608 (49.51%)
#
# 24
#
# Test set: Average loss: 0.0037, Accuracy: 296/608 (48.68%)
#
# 25
#
# Test set: Average loss: 0.0028, Accuracy: 615/1000 (61.50%)
#
# 26
#
# Test set: Average loss: 0.0026, Accuracy: 675/1000 (67.50%)
#
# 27
#
# Test set: Average loss: 0.0070, Accuracy: 469/1000 (46.90%)
#
# 28
#
# Test set: Average loss: 0.0031, Accuracy: 578/1000 (57.80%)
#
# 29
#
# Test set: Average loss: 0.0031, Accuracy: 439/1000 (43.90%)
#
# 30
#
# Test set: Average loss: 0.0045, Accuracy: 442/999 (44.24%)
#
# 31
#
# Test set: Average loss: 0.0102, Accuracy: 164/1000 (16.40%)
#
# 32
#
# Test set: Average loss: 0.0028, Accuracy: 727/1000 (72.70%)
#
# 33
#
# Test set: Average loss: 0.0032, Accuracy: 636/1000 (63.60%)
#
# 34
#
# Test set: Average loss: 0.0032, Accuracy: 605/1000 (60.50%)
#
# 35
#
# Test set: Average loss: 0.0079, Accuracy: 319/1000 (31.90%)
#
# 36
#
# Test set: Average loss: 0.0060, Accuracy: 520/1000 (52.00%)
#
# 37
#
# Test set: Average loss: 0.0030, Accuracy: 577/1000 (57.70%)
#
# 38
#
# Test set: Average loss: 0.0033, Accuracy: 538/1000 (53.80%)
#
# begin
# Train Epoch: 9 [0/149557 (0%)]	Loss: 1.144047
# Train Epoch: 9 [120320/149557 (80%)]	Loss: 1.210814
# Train Epoch: 9 [122880/149557 (82%)]	Loss: 1.192792
# Train Epoch: 9 [125440/149557 (84%)]	Loss: 1.231833
# Train Epoch: 9 [128000/149557 (85%)]	Loss: 1.176634
# Train Epoch: 9 [130560/149557 (87%)]	Loss: 1.305980
# Train Epoch: 9 [133120/149557 (89%)]	Loss: 1.194181
# Train Epoch: 9 [135680/149557 (91%)]	Loss: 1.240172
# Train Epoch: 9 [138240/149557 (92%)]	Loss: 1.231070
# Train Epoch: 9 [140800/149557 (94%)]	Loss: 1.206577
# Train Epoch: 9 [143360/149557 (96%)]	Loss: 1.168868
# Train Epoch: 9 [145920/149557 (97%)]	Loss: 1.155858
# Train Epoch: 9 [148480/149557 (99%)]	Loss: 1.195965
# 0
#
# Test set: Average loss: 0.0031, Accuracy: 427/1000 (42.70%)
#
# 1
#
# Test set: Average loss: 0.0033, Accuracy: 505/1000 (50.50%)
#
# 2
#
# Test set: Average loss: 0.0032, Accuracy: 389/1000 (38.90%)
#
# 3
#
# Test set: Average loss: 0.0028, Accuracy: 545/1000 (54.50%)
#
# 4
#
# Test set: Average loss: 0.0030, Accuracy: 513/1000 (51.30%)
#
# 5
#
# Test set: Average loss: 0.0030, Accuracy: 612/1000 (61.20%)
#
# 6
#
# Test set: Average loss: 0.0032, Accuracy: 498/1000 (49.80%)
#
# 7
#
# Test set: Average loss: 0.0119, Accuracy: 121/999 (12.11%)
#
# 8
#
# Test set: Average loss: 0.0031, Accuracy: 462/1000 (46.20%)
#
# 9
#
# Test set: Average loss: 0.0027, Accuracy: 670/1000 (67.00%)
#
# 10
#
# Test set: Average loss: 0.0030, Accuracy: 442/1000 (44.20%)
#
# 11
#
# Test set: Average loss: 0.0026, Accuracy: 643/1000 (64.30%)
#
# 12
#
# Test set: Average loss: 0.0024, Accuracy: 784/1000 (78.40%)
#
# 13
#
# Test set: Average loss: 0.0029, Accuracy: 637/1000 (63.70%)
#
# 14
#
# Test set: Average loss: 0.0024, Accuracy: 758/1000 (75.80%)
#
# 15
#
# Test set: Average loss: 0.0070, Accuracy: 443/1000 (44.30%)
#
# 16
#
# Test set: Average loss: 0.0066, Accuracy: 481/1000 (48.10%)
#
# 17
#
# Test set: Average loss: 0.0042, Accuracy: 467/1000 (46.70%)
#
# 18
#
# Test set: Average loss: 0.0041, Accuracy: 459/1000 (45.90%)
#
# 19
#
# Test set: Average loss: 0.0084, Accuracy: 240/999 (24.02%)
#
# 20
#
# Test set: Average loss: 0.0035, Accuracy: 460/1000 (46.00%)
#
# 21
#
# Test set: Average loss: 0.0143, Accuracy: 17/900 (1.89%)
#
# 22
#
# Test set: Average loss: 0.0049, Accuracy: 145/312 (46.47%)
#
# 23
#
# Test set: Average loss: 0.0038, Accuracy: 312/608 (51.32%)
#
# 24
#
# Test set: Average loss: 0.0037, Accuracy: 296/608 (48.68%)
#
# 25
#
# Test set: Average loss: 0.0028, Accuracy: 609/1000 (60.90%)
#
# 26
#
# Test set: Average loss: 0.0026, Accuracy: 709/1000 (70.90%)
# Train Epoch: 10 [76800/149557 (51%)]	Loss: 1.174040
# Train Epoch: 10 [79360/149557 (53%)]	Loss: 1.152307
# Train Epoch: 10 [81920/149557 (55%)]	Loss: 1.227078
# Train Epoch: 10 [84480/149557 (56%)]	Loss: 1.088382
# Train Epoch: 10 [87040/149557 (58%)]	Loss: 1.185901
# Train Epoch: 10 [89600/149557 (60%)]	Loss: 1.173671
# Train Epoch: 10 [92160/149557 (62%)]	Loss: 1.099371
# Train Epoch: 10 [94720/149557 (63%)]	Loss: 1.163844
# Train Epoch: 10 [97280/149557 (65%)]	Loss: 1.200977
# Train Epoch: 10 [99840/149557 (67%)]	Loss: 1.172594
# Train Epoch: 10 [102400/149557 (68%)]	Loss: 1.184321
# Train Epoch: 10 [104960/149557 (70%)]	Loss: 1.060163
# Train Epoch: 10 [107520/149557 (72%)]	Loss: 1.100741
# Train Epoch: 10 [110080/149557 (74%)]	Loss: 1.314253
# Train Epoch: 10 [112640/149557 (75%)]	Loss: 1.247561
# Train Epoch: 10 [115200/149557 (77%)]	Loss: 1.134175
# Train Epoch: 10 [117760/149557 (79%)]	Loss: 1.098085
# Train Epoch: 10 [120320/149557 (80%)]	Loss: 1.198650
# Train Epoch: 10 [122880/149557 (82%)]	Loss: 1.263596
# Train Epoch: 10 [125440/149557 (84%)]	Loss: 1.161629
# Train Epoch: 10 [128000/149557 (85%)]	Loss: 1.127281
# Train Epoch: 10 [130560/149557 (87%)]	Loss: 1.207574
# Train Epoch: 10 [133120/149557 (89%)]	Loss: 1.065695
# Train Epoch: 10 [135680/149557 (91%)]	Loss: 1.136055
# Train Epoch: 10 [138240/149557 (92%)]	Loss: 1.147511
# Train Epoch: 10 [140800/149557 (94%)]	Loss: 1.204251
# Train Epoch: 10 [143360/149557 (96%)]	Loss: 1.133099
# Train Epoch: 10 [145920/149557 (97%)]	Loss: 1.145158
# Train Epoch: 10 [148480/149557 (99%)]	Loss: 1.277429
# 0
#
# Test set: Average loss: 0.0031, Accuracy: 418/1000 (41.80%)
#
# 1
#
# Test set: Average loss: 0.0033, Accuracy: 503/1000 (50.30%)
#
# 2
#
# Test set: Average loss: 0.0032, Accuracy: 386/1000 (38.60%)
#
# 3
#
# Test set: Average loss: 0.0028, Accuracy: 526/1000 (52.60%)
#
# 4
#
# Test set: Average loss: 0.0030, Accuracy: 524/1000 (52.40%)
#
# 5
#
# Test set: Average loss: 0.0030, Accuracy: 599/1000 (59.90%)
#
# 6
#
# Test set: Average loss: 0.0031, Accuracy: 507/1000 (50.70%)
#
# 7
#
# Test set: Average loss: 0.0116, Accuracy: 152/999 (15.22%)
#
# 8
#
# Test set: Average loss: 0.0031, Accuracy: 455/1000 (45.50%)
#
# 9
#
# Test set: Average loss: 0.0026, Accuracy: 667/1000 (66.70%)
#
# 10
#
# Test set: Average loss: 0.0030, Accuracy: 442/1000 (44.20%)
#
# 11
#
# Test set: Average loss: 0.0026, Accuracy: 644/1000 (64.40%)
#
# 12
#
# Test set: Average loss: 0.0024, Accuracy: 771/1000 (77.10%)
#
# 13
#
# Test set: Average loss: 0.0029, Accuracy: 627/1000 (62.70%)
#
# 14
#
# Test set: Average loss: 0.0024, Accuracy: 742/1000 (74.20%)
#
# 15
#
# Test set: Average loss: 0.0068, Accuracy: 439/1000 (43.90%)
#
# 16
#
# Test set: Average loss: 0.0053, Accuracy: 569/1000 (56.90%)
#
# 17
#
# Test set: Average loss: 0.0042, Accuracy: 459/1000 (45.90%)
#
# 18
#
# Test set: Average loss: 0.0041, Accuracy: 456/1000 (45.60%)
#
# 19
#
# Test set: Average loss: 0.0079, Accuracy: 279/999 (27.93%)
#
# 20
#
# Test set: Average loss: 0.0036, Accuracy: 474/1000 (47.40%)
#
# 21
#
# Test set: Average loss: 0.0136, Accuracy: 24/900 (2.67%)
#
# 22
#
# Test set: Average loss: 0.0048, Accuracy: 147/312 (47.12%)
#
# 23
#
# Test set: Average loss: 0.0038, Accuracy: 304/608 (50.00%)
#
# 24
#
# Test set: Average loss: 0.0037, Accuracy: 304/608 (50.00%)
#
# 25
#
# Test set: Average loss: 0.0028, Accuracy: 616/1000 (61.60%)
#
# 26
#
# Test set: Average loss: 0.0025, Accuracy: 698/1000 (69.80%)
#
# 27
#
# Test set: Average loss: 0.0070, Accuracy: 461/1000 (46.10%)
#
# 28
#
# Test set: Average loss: 0.0029, Accuracy: 592/1000 (59.20%)
#
# 29
#
# Test set: Average loss: 0.0032, Accuracy: 396/1000 (39.60%)
#
# 30
#
# Test set: Average loss: 0.0043, Accuracy: 448/999 (44.84%)
#
# 31
#
# Test set: Average loss: 0.0096, Accuracy: 178/1000 (17.80%)
#
# 32
#
# Test set: Average loss: 0.0027, Accuracy: 719/1000 (71.90%)
#
# 33
#
# Test set: Average loss: 0.0030, Accuracy: 664/1000 (66.40%)
#
# 34
#
# Test set: Average loss: 0.0031, Accuracy: 611/1000 (61.10%)
#
# 35
#
# Test set: Average loss: 0.0073, Accuracy: 370/1000 (37.00%)
#
# 36
#
# Test set: Average loss: 0.0051, Accuracy: 588/1000 (58.80%)
#
# 37
#
# Test set: Average loss: 0.0029, Accuracy: 580/1000 (58.00%)
#
# 38
#
# Test set: Average loss: 0.0031, Accuracy: 556/1000 (55.60%)
#
# begin
# Train Epoch: 11 [0/149557 (0%)]	Loss: 1.053752
# Train Epoch: 11 [2560/149557 (2%)]	Loss: 1.090235
# Train Epoch: 11 [5120/149557 (3%)]	Loss: 1.207615
# Train Epoch: 11 [7680/149557 (5%)]	Loss: 1.175866
# Train Epoch: 11 [10240/149557 (7%)]	Loss: 1.128169
# Train Epoch: 11 [12800/149557 (9%)]	Loss: 1.141590
# Train Epoch: 11 [15360/149557 (10%)]	Loss: 1.258595
# Train Epoch: 11 [17920/149557 (12%)]	Loss: 1.184529
# Train Epoch: 11 [20480/149557 (14%)]	Loss: 1.132696
# Train Epoch: 11 [23040/149557 (15%)]	Loss: 1.193186
# Train Epoch: 11 [25600/149557 (17%)]	Loss: 1.178224
# Train Epoch: 11 [28160/149557 (19%)]	Loss: 1.110911
# Train Epoch: 11 [30720/149557 (21%)]	Loss: 1.183236
# Train Epoch: 11 [33280/149557 (22%)]	Loss: 1.224337
#
# 1
#
# Test set: Average loss: 0.0031, Accuracy: 502/1000 (50.20%)
#
# 2
#
# Test set: Average loss: 0.0032, Accuracy: 408/1000 (40.80%)
#
# 3
#
# Test set: Average loss: 0.0028, Accuracy: 527/1000 (52.70%)
#
# 4
#
# Test set: Average loss: 0.0029, Accuracy: 519/1000 (51.90%)
#
# 5
#
# Test set: Average loss: 0.0029, Accuracy: 594/1000 (59.40%)
#
# 6
#
# Test set: Average loss: 0.0030, Accuracy: 514/1000 (51.40%)
#
# 7
#
# Test set: Average loss: 0.0113, Accuracy: 144/999 (14.41%)
#
# 8
#
# Test set: Average loss: 0.0030, Accuracy: 449/1000 (44.90%)
#
# 9
#
# Test set: Average loss: 0.0026, Accuracy: 701/1000 (70.10%)
#
# 10
#
# Test set: Average loss: 0.0030, Accuracy: 449/1000 (44.90%)
#
# 11
#
# Test set: Average loss: 0.0026, Accuracy: 645/1000 (64.50%)
#
# 12
#
# Test set: Average loss: 0.0024, Accuracy: 780/1000 (78.00%)
#
# 13
#
# Test set: Average loss: 0.0028, Accuracy: 625/1000 (62.50%)
#
# 14
#
# Test set: Average loss: 0.0024, Accuracy: 772/1000 (77.20%)
#
# 15
#
# Test set: Average loss: 0.0062, Accuracy: 485/1000 (48.50%)
#
# 16
#
# Test set: Average loss: 0.0054, Accuracy: 545/1000 (54.50%)
#
# 17
#
# Test set: Average loss: 0.0041, Accuracy: 473/1000 (47.30%)
#
# 18
#
# Test set: Average loss: 0.0040, Accuracy: 473/1000 (47.30%)
#
# 19
#
# Test set: Average loss: 0.0077, Accuracy: 283/999 (28.33%)
#
# 20
#
# Test set: Average loss: 0.0035, Accuracy: 453/1000 (45.30%)
#
# 21
#
# Test set: Average loss: 0.0130, Accuracy: 42/900 (4.67%)
#
# 22
#
# Test set: Average loss: 0.0048, Accuracy: 150/312 (48.08%)
#
# 23
#
# Test set: Average loss: 0.0037, Accuracy: 322/608 (52.96%)
#
# 24
#
# Test set: Average loss: 0.0036, Accuracy: 304/608 (50.00%)
#
# 25
#
# Test set: Average loss: 0.0027, Accuracy: 625/1000 (62.50%)
#
# 26
#
# Test set: Average loss: 0.0025, Accuracy: 715/1000 (71.50%)
#
# 27
#
# Test set: Average loss: 0.0061, Accuracy: 500/1000 (50.00%)
#
# 28
#
# Test set: Average loss: 0.0029, Accuracy: 591/1000 (59.10%)
#
# 29
#
# Test set: Average loss: 0.0031, Accuracy: 401/1000 (40.10%)
#
# 30
#
# Test set: Average loss: 0.0043, Accuracy: 439/999 (43.94%)
#
# 31
#
# Test set: Average loss: 0.0095, Accuracy: 173/1000 (17.30%)
#
# 32
#
# Test set: Average loss: 0.0027, Accuracy: 702/1000 (70.20%)
#
# 33
#
# Test set: Average loss: 0.0030, Accuracy: 666/1000 (66.60%)
#
# 34
#
# Test set: Average loss: 0.0030, Accuracy: 628/1000 (62.80%)
#
# 35
#
# Test set: Average loss: 0.0067, Accuracy: 407/1000 (40.70%)
#
# 36
#
# Test set: Average loss: 0.0048, Accuracy: 603/1000 (60.30%)
#
# Train Epoch: 12 [110080/149557 (74%)]	Loss: 1.241229
# Train Epoch: 12 [112640/149557 (75%)]	Loss: 1.183513
# Train Epoch: 12 [115200/149557 (77%)]	Loss: 1.060128
# Train Epoch: 12 [117760/149557 (79%)]	Loss: 1.157846
# Train Epoch: 12 [120320/149557 (80%)]	Loss: 1.182053
# Train Epoch: 12 [122880/149557 (82%)]	Loss: 1.097927
# Train Epoch: 12 [125440/149557 (84%)]	Loss: 1.091716
# Train Epoch: 12 [128000/149557 (85%)]	Loss: 0.980487
# Train Epoch: 12 [130560/149557 (87%)]	Loss: 1.123287
# Train Epoch: 12 [133120/149557 (89%)]	Loss: 1.118944
# Train Epoch: 12 [135680/149557 (91%)]	Loss: 1.048911
# Train Epoch: 12 [138240/149557 (92%)]	Loss: 1.089417
# Train Epoch: 12 [140800/149557 (94%)]	Loss: 1.160709
# Train Epoch: 12 [143360/149557 (96%)]	Loss: 1.057899
# Train Epoch: 12 [145920/149557 (97%)]	Loss: 1.182496
# Train Epoch: 12 [148480/149557 (99%)]	Loss: 1.081962
# 0
#
# Test set: Average loss: 0.0030, Accuracy: 438/1000 (43.80%)
#
# 1
#
# Test set: Average loss: 0.0031, Accuracy: 504/1000 (50.40%)
#
# 2
#
# Test set: Average loss: 0.0032, Accuracy: 413/1000 (41.30%)
#
# 3
#
# Test set: Average loss: 0.0028, Accuracy: 547/1000 (54.70%)
#
# 4
#
# Test set: Average loss: 0.0029, Accuracy: 537/1000 (53.70%)
#
# 5
#
# Test set: Average loss: 0.0029, Accuracy: 600/1000 (60.00%)
#
# 6
#
# Test set: Average loss: 0.0030, Accuracy: 515/1000 (51.50%)
#
# 7
#
# Test set: Average loss: 0.0107, Accuracy: 182/999 (18.22%)
#
# 8
#
# Test set: Average loss: 0.0030, Accuracy: 464/1000 (46.40%)
#
# 9
#
# Test set: Average loss: 0.0026, Accuracy: 692/1000 (69.20%)
#
# 10
#
# Test set: Average loss: 0.0030, Accuracy: 438/1000 (43.80%)
#
# 11
#
# Test set: Average loss: 0.0026, Accuracy: 622/1000 (62.20%)
#
# 12
#
# Test set: Average loss: 0.0024, Accuracy: 768/1000 (76.80%)
#
# 13
#
# Test set: Average loss: 0.0028, Accuracy: 625/1000 (62.50%)
#
# 14
#
# Test set: Average loss: 0.0024, Accuracy: 741/1000 (74.10%)
#
# 15
#
# Test set: Average loss: 0.0061, Accuracy: 507/1000 (50.70%)
#
# 16
#
# Test set: Average loss: 0.0048, Accuracy: 586/1000 (58.60%)
#
# 17
#
# Test set: Average loss: 0.0040, Accuracy: 478/1000 (47.80%)
#
# 18
#
# Test set: Average loss: 0.0040, Accuracy: 464/1000 (46.40%)
#
# 19
#
# Test set: Average loss: 0.0073, Accuracy: 301/999 (30.13%)
#
# 20
#
# Test set: Average loss: 0.0034, Accuracy: 479/1000 (47.90%)
#
# 21
#
# Test set: Average loss: 0.0128, Accuracy: 48/900 (5.33%)
#
# 22
#
# Test set: Average loss: 0.0048, Accuracy: 151/312 (48.40%)
#
# 23
#
# Test set: Average loss: 0.0037, Accuracy: 307/608 (50.49%)
#
# 11
#
# Test set: Average loss: 0.0026, Accuracy: 634/1000 (63.40%)
#
# 12
#
# Test set: Average loss: 0.0024, Accuracy: 777/1000 (77.70%)
#
# 13
#
# Test set: Average loss: 0.0028, Accuracy: 611/1000 (61.10%)
#
# 14
#
# Test set: Average loss: 0.0023, Accuracy: 766/1000 (76.60%)
#
# 15
#
# Test set: Average loss: 0.0057, Accuracy: 529/1000 (52.90%)
#
# 16
#
# Test set: Average loss: 0.0047, Accuracy: 585/1000 (58.50%)
#
# 17
#
# Test set: Average loss: 0.0040, Accuracy: 475/1000 (47.50%)
#
# 18
#
# Test set: Average loss: 0.0040, Accuracy: 468/1000 (46.80%)
#
# 19
#
# Test set: Average loss: 0.0073, Accuracy: 297/999 (29.73%)
#
# 20
#
# Test set: Average loss: 0.0035, Accuracy: 459/1000 (45.90%)
#
# 21
#
# Test set: Average loss: 0.0122, Accuracy: 46/900 (5.11%)
#
# 22
#
# Test set: Average loss: 0.0048, Accuracy: 156/312 (50.00%)
#
# 23
#
# Test set: Average loss: 0.0037, Accuracy: 315/608 (51.81%)
#
# 24
#
# Test set: Average loss: 0.0037, Accuracy: 296/608 (48.68%)
#
# 25
#
# Test set: Average loss: 0.0027, Accuracy: 643/1000 (64.30%)
#
# 26
#
# Test set: Average loss: 0.0025, Accuracy: 705/1000 (70.50%)
#
# 27
#
# Test set: Average loss: 0.0054, Accuracy: 516/1000 (51.60%)
#
# 28
#
# Test set: Average loss: 0.0028, Accuracy: 571/1000 (57.10%)
#
# 29
#
# Test set: Average loss: 0.0031, Accuracy: 421/1000 (42.10%)
#
# 30
#
# Test set: Average loss: 0.0042, Accuracy: 445/999 (44.54%)
#
# 31
#
# Test set: Average loss: 0.0094, Accuracy: 167/1000 (16.70%)
#
# 32
#
# Test set: Average loss: 0.0027, Accuracy: 709/1000 (70.90%)
#
# 33
#
# Test set: Average loss: 0.0031, Accuracy: 655/1000 (65.50%)
#
# 34
#
# Test set: Average loss: 0.0031, Accuracy: 598/1000 (59.80%)
#
# 35
#
# Test set: Average loss: 0.0057, Accuracy: 457/1000 (45.70%)
#
# 36
#
# Test set: Average loss: 0.0038, Accuracy: 656/1000 (65.60%)
#
# 37
#
# Test set: Average loss: 0.0029, Accuracy: 576/1000 (57.60%)
#
# 38
#
# Test set: Average loss: 0.0030, Accuracy: 556/1000 (55.60%)
#
# begin
# Train Epoch: 14 [0/149557 (0%)]	Loss: 1.064368
# Train Epoch: 14 [2560/149557 (2%)]	Loss: 1.105217
# Train Epoch: 14 [5120/149557 (3%)]	Loss: 1.133302
# Train Epoch: 14 [7680/149557 (5%)]	Loss: 1.107210
# Train Epoch: 14 [10240/149557 (7%)]	Loss: 1.062971
# Train Epoch: 14 [12800/149557 (9%)]	Loss: 1.084267
# Train Epoch: 14 [15360/149557 (10%)]	Loss: 0.975709
# Train Epoch: 14 [17920/149557 (12%)]	Loss: 1.062020
# Train Epoch: 14 [20480/149557 (14%)]	Loss: 1.045669
# Train Epoch: 14 [23040/149557 (15%)]	Loss: 1.061192
# Train Epoch: 14 [143360/149557 (96%)]	Loss: 1.068413
# Train Epoch: 14 [145920/149557 (97%)]	Loss: 1.019135
# Train Epoch: 14 [148480/149557 (99%)]	Loss: 1.000953
# 0
#
# Test set: Average loss: 0.0031, Accuracy: 451/1000 (45.10%)
#
# 1
#
# Test set: Average loss: 0.0032, Accuracy: 500/1000 (50.00%)
#
# 2
#
# Test set: Average loss: 0.0032, Accuracy: 409/1000 (40.90%)
#
# 3
#
# Test set: Average loss: 0.0029, Accuracy: 539/1000 (53.90%)
#
# 4
#
# Test set: Average loss: 0.0029, Accuracy: 540/1000 (54.00%)
#
# 5
#
# Test set: Average loss: 0.0030, Accuracy: 597/1000 (59.70%)
#
# 6
#
# Test set: Average loss: 0.0031, Accuracy: 504/1000 (50.40%)
#
# 7
#
# Test set: Average loss: 0.0100, Accuracy: 198/999 (19.82%)
#
# 8
#
# Test set: Average loss: 0.0030, Accuracy: 445/1000 (44.50%)
#
# 9
#
# Test set: Average loss: 0.0026, Accuracy: 684/1000 (68.40%)
#
# 10
#
# Test set: Average loss: 0.0030, Accuracy: 447/1000 (44.70%)
#
# 11
#
# Test set: Average loss: 0.0026, Accuracy: 633/1000 (63.30%)
#
# 12
#
# Test set: Average loss: 0.0023, Accuracy: 785/1000 (78.50%)
#
# 13
#
# Test set: Average loss: 0.0028, Accuracy: 620/1000 (62.00%)
#
# 14
#
# Test set: Average loss: 0.0023, Accuracy: 773/1000 (77.30%)
#
# 15
#
# Test set: Average loss: 0.0052, Accuracy: 560/1000 (56.00%)
#
# 16
#
# Test set: Average loss: 0.0036, Accuracy: 683/1000 (68.30%)
#
# 17
#
# Test set: Average loss: 0.0041, Accuracy: 469/1000 (46.90%)
#
# 18
#
# Test set: Average loss: 0.0041, Accuracy: 452/1000 (45.20%)
#
# 19
#
# Test set: Average loss: 0.0068, Accuracy: 324/999 (32.43%)
#
# 20
#
# Test set: Average loss: 0.0036, Accuracy: 460/1000 (46.00%)
#
# 21
#
# Test set: Average loss: 0.0119, Accuracy: 65/900 (7.22%)
#
# 22
#
# Test set: Average loss: 0.0048, Accuracy: 153/312 (49.04%)
#
# 23
#
# Test set: Average loss: 0.0037, Accuracy: 305/608 (50.16%)
#
# 24
#
# Test set: Average loss: 0.0037, Accuracy: 291/608 (47.86%)
#
# 25
#
# Test set: Average loss: 0.0027, Accuracy: 640/1000 (64.00%)
#
# 26
#
# Test set: Average loss: 0.0025, Accuracy: 703/1000 (70.30%)
#
# 27
#
# Test set: Average loss: 0.0056, Accuracy: 508/1000 (50.80%)
#
# 28
#
# Test set: Average loss: 0.0028, Accuracy: 564/1000 (56.40%)
#
# 29
#
# Test set: Average loss: 0.0032, Accuracy: 415/1000 (41.50%)
#
# 30
#
# Test set: Average loss: 0.0041, Accuracy: 454/999 (45.45%)
#
# 31
#
# Test set: Average loss: 0.0092, Accuracy: 183/1000 (18.30%)
#
# 32
#
# Test set: Average loss: 0.0026, Accuracy: 720/1000 (72.00%)
#
# 33
#
# Test set: Average loss: 0.0029, Accuracy: 677/1000 (67.70%)
#
# 34
#
# Train Epoch: 27 [125440/149557 (84%)]	Loss: 0.888345
# Train Epoch: 27 [128000/149557 (85%)]	Loss: 0.967806
# Train Epoch: 27 [130560/149557 (87%)]	Loss: 0.936641
# Train Epoch: 27 [133120/149557 (89%)]	Loss: 0.869573
# Train Epoch: 27 [135680/149557 (91%)]	Loss: 0.801135
# Train Epoch: 27 [138240/149557 (92%)]	Loss: 0.897806
# Train Epoch: 27 [140800/149557 (94%)]	Loss: 0.868672
# Train Epoch: 27 [143360/149557 (96%)]	Loss: 0.846091
# Train Epoch: 27 [145920/149557 (97%)]	Loss: 0.820707
# Train Epoch: 27 [148480/149557 (99%)]	Loss: 0.899857
# 0
#
# Test set: Average loss: 0.0031, Accuracy: 509/1000 (50.90%)
#
# 1
#
# Test set: Average loss: 0.0031, Accuracy: 512/1000 (51.20%)
#
# 2
#
# Test set: Average loss: 0.0032, Accuracy: 435/1000 (43.50%)
#
# 3
#
# Test set: Average loss: 0.0029, Accuracy: 553/1000 (55.30%)
#
# 4
#
# Test set: Average loss: 0.0029, Accuracy: 551/1000 (55.10%)
#
# 5
#
# Test set: Average loss: 0.0029, Accuracy: 584/1000 (58.40%)
#
# 6
#
# Test set: Average loss: 0.0031, Accuracy: 506/1000 (50.60%)
#
# 7
#
# Test set: Average loss: 0.0060, Accuracy: 382/999 (38.24%)
#
# 8
#
# Test set: Average loss: 0.0031, Accuracy: 505/1000 (50.50%)
#
# 9
#
# Test set: Average loss: 0.0025, Accuracy: 650/1000 (65.00%)
#
# 10
#
# Test set: Average loss: 0.0030, Accuracy: 471/1000 (47.10%)
#
# 11
#
# Test set: Average loss: 0.0027, Accuracy: 602/1000 (60.20%)
#
# 12
#
# Test set: Average loss: 0.0025, Accuracy: 705/1000 (70.50%)
#
# 13
#
# Test set: Average loss: 0.0029, Accuracy: 555/1000 (55.50%)
#
# 14
#
# Test set: Average loss: 0.0024, Accuracy: 715/1000 (71.50%)
#
# 15
#
# Test set: Average loss: 0.0034, Accuracy: 672/1000 (67.20%)
#
# 16
#
# Test set: Average loss: 0.0021, Accuracy: 803/1000 (80.30%)
#
# 17
#
# Test set: Average loss: 0.0036, Accuracy: 477/1000 (47.70%)
#
# 18
#
# Test set: Average loss: 0.0039, Accuracy: 460/1000 (46.00%)
#
# 19
#
# Test set: Average loss: 0.0049, Accuracy: 350/999 (35.04%)
#
# 20
#
# Test set: Average loss: 0.0035, Accuracy: 518/1000 (51.80%)
#
# 21
#
# Test set: Average loss: 0.0090, Accuracy: 142/900 (15.78%)
#
# 22
#
# Test set: Average loss: 0.0044, Accuracy: 176/312 (56.41%)
#
# 23
#
# Test set: Average loss: 0.0035, Accuracy: 341/608 (56.09%)
#
# 24
#
# Test set: Average loss: 0.0036, Accuracy: 338/608 (55.59%)
#
# 25
#
# Test set: Average loss: 0.0027, Accuracy: 639/1000 (63.90%)
#
# 26
#
# Test set: Average loss: 0.0024, Accuracy: 679/1000 (67.90%)
#
# 27
#
# Test set: Average loss: 0.0039, Accuracy: 592/1000 (59.20%)
#
# 28
#
# Test set: Average loss: 0.0028, Accuracy: 568/1000 (56.80%)
# Train Epoch: 28 [84480/149557 (56%)]	Loss: 0.881725
# Train Epoch: 28 [87040/149557 (58%)]	Loss: 0.855842
# Train Epoch: 28 [89600/149557 (60%)]	Loss: 0.821334
# Train Epoch: 28 [92160/149557 (62%)]	Loss: 0.823409
# Train Epoch: 28 [94720/149557 (63%)]	Loss: 0.863304
# Train Epoch: 28 [97280/149557 (65%)]	Loss: 0.849063
# Train Epoch: 28 [99840/149557 (67%)]	Loss: 0.853604
# Train Epoch: 28 [102400/149557 (68%)]	Loss: 0.855158
# Train Epoch: 28 [104960/149557 (70%)]	Loss: 0.864431
# Train Epoch: 28 [107520/149557 (72%)]	Loss: 0.821913
# Train Epoch: 28 [110080/149557 (74%)]	Loss: 0.906274
# Train Epoch: 28 [112640/149557 (75%)]	Loss: 0.900668
# Train Epoch: 28 [115200/149557 (77%)]	Loss: 0.829305
# Train Epoch: 28 [117760/149557 (79%)]	Loss: 0.828083
# Train Epoch: 28 [120320/149557 (80%)]	Loss: 0.805682
# Train Epoch: 28 [122880/149557 (82%)]	Loss: 0.857671
# Train Epoch: 28 [125440/149557 (84%)]	Loss: 0.814573
# Train Epoch: 28 [128000/149557 (85%)]	Loss: 0.974478
# Train Epoch: 28 [130560/149557 (87%)]	Loss: 0.819506
# Train Epoch: 28 [133120/149557 (89%)]	Loss: 0.858660
# Train Epoch: 28 [135680/149557 (91%)]	Loss: 0.884598
# Train Epoch: 28 [138240/149557 (92%)]	Loss: 0.852321
# Train Epoch: 28 [140800/149557 (94%)]	Loss: 0.823341
# Train Epoch: 28 [143360/149557 (96%)]	Loss: 0.879775
# Train Epoch: 28 [145920/149557 (97%)]	Loss: 0.787233
# Train Epoch: 28 [148480/149557 (99%)]	Loss: 0.825705
# 0
#
# Test set: Average loss: 0.0031, Accuracy: 468/1000 (46.80%)
#
# 1
#
# Test set: Average loss: 0.0031, Accuracy: 524/1000 (52.40%)
#
# 2
#
# Test set: Average loss: 0.0033, Accuracy: 419/1000 (41.90%)
#
# 3
#
# Test set: Average loss: 0.0029, Accuracy: 546/1000 (54.60%)
#
# 4
#
# Test set: Average loss: 0.0030, Accuracy: 546/1000 (54.60%)
#
# 5
#
# Test set: Average loss: 0.0029, Accuracy: 578/1000 (57.80%)
#
# 6
#
# Test set: Average loss: 0.0031, Accuracy: 514/1000 (51.40%)
#
# 7
#
# Test set: Average loss: 0.0056, Accuracy: 416/999 (41.64%)
#
# 8
#
# Test set: Average loss: 0.0032, Accuracy: 485/1000 (48.50%)
#
# 9
#
# Test set: Average loss: 0.0025, Accuracy: 682/1000 (68.20%)
#
# 10
#
# Test set: Average loss: 0.0031, Accuracy: 465/1000 (46.50%)
#
# 11
#
# Test set: Average loss: 0.0026, Accuracy: 612/1000 (61.20%)
#
# 12
#
# Test set: Average loss: 0.0023, Accuracy: 741/1000 (74.10%)
#
# 13
#
# Test set: Average loss: 0.0028, Accuracy: 593/1000 (59.30%)
#
# 14
#
# Test set: Average loss: 0.0022, Accuracy: 757/1000 (75.70%)
#
# 15
#
# Test set: Average loss: 0.0033, Accuracy: 678/1000 (67.80%)
#
# 16
#
# Test set: Average loss: 0.0020, Accuracy: 798/1000 (79.80%)
#
# 17
#
# Test set: Average loss: 0.0033, Accuracy: 513/1000 (51.30%)
#
# 18
#
# Test set: Average loss: 0.0038, Accuracy: 454/1000 (45.40%)
#
# 19
#
# Test set: Average loss: 0.0051, Accuracy: 337/999 (33.73%)
#
# 20
#
# Test set: Average loss: 0.0032, Accuracy: 487/1000 (48.70%)
#
# 21
#
# Test set: Average loss: 0.0089, Accuracy: 144/900 (16.00%)
#
# 22
#
# Test set: Average loss: 0.0045, Accuracy: 179/312 (57.37%)
#
# 23
#
# Test set: Average loss: 0.0035, Accuracy: 346/608 (56.91%)
#
# 24
#
# Test set: Average loss: 0.0036, Accuracy: 326/608 (53.62%)
#
# 25
#
# Test set: Average loss: 0.0026, Accuracy: 642/1000 (64.20%)
#
# 26
#
# Test set: Average loss: 0.0023, Accuracy: 687/1000 (68.70%)
#
# 27
#
# Test set: Average loss: 0.0038, Accuracy: 589/1000 (58.90%)
#
# 28
#
# Test set: Average loss: 0.0028, Accuracy: 555/1000 (55.50%)
#
# 29
#
# Test set: Average loss: 0.0032, Accuracy: 447/1000 (44.70%)
#
# 30
#
# Test set: Average loss: 0.0042, Accuracy: 441/999 (44.14%)
#
# 31
#
# Test set: Average loss: 0.0087, Accuracy: 203/1000 (20.30%)
#
# 32
#
# Test set: Average loss: 0.0026, Accuracy: 709/1000 (70.90%)
#
# 33
#
# Test set: Average loss: 0.0028, Accuracy: 650/1000 (65.00%)
#
# 34
#
# Test set: Average loss: 0.0028, Accuracy: 637/1000 (63.70%)
#
# 35
#
# Test set: Average loss: 0.0032, Accuracy: 615/1000 (61.50%)
#
# 36
#
# Test set: Average loss: 0.0024, Accuracy: 750/1000 (75.00%)
#
# 37
#
# Test set: Average loss: 0.0030, Accuracy: 568/1000 (56.80%)
#
# 38
#
# Test set: Average loss: 0.0030, Accuracy: 559/1000 (55.90%)
#
# begin
# Train Epoch: 29 [0/149557 (0%)]	Loss: 0.968698
# Train Epoch: 29 [2560/149557 (2%)]	Loss: 0.840445
# Train Epoch: 29 [5120/149557 (3%)]	Loss: 0.809594
# Train Epoch: 29 [7680/149557 (5%)]	Loss: 0.737975
# Train Epoch: 29 [10240/149557 (7%)]	Loss: 0.861602
# Train Epoch: 29 [12800/149557 (9%)]	Loss: 0.868617
# Train Epoch: 29 [15360/149557 (10%)]	Loss: 0.866608
# Train Epoch: 29 [17920/149557 (12%)]	Loss: 0.897258
# Train Epoch: 29 [20480/149557 (14%)]	Loss: 0.891580
# Train Epoch: 29 [23040/149557 (15%)]	Loss: 0.825749
# Train Epoch: 29 [25600/149557 (17%)]	Loss: 0.883253
# Train Epoch: 29 [28160/149557 (19%)]	Loss: 0.858312
# Train Epoch: 29 [30720/149557 (21%)]	Loss: 0.872380
# Train Epoch: 29 [33280/149557 (22%)]	Loss: 0.813676
# Train Epoch: 29 [35840/149557 (24%)]	Loss: 0.845979
# Train Epoch: 29 [38400/149557 (26%)]	Loss: 0.822737
# Test set: Average loss: 0.0033, Accuracy: 418/1000 (41.80%)
#
# 3
#
# Test set: Average loss: 0.0029, Accuracy: 557/1000 (55.70%)
#
# 4
#
# Test set: Average loss: 0.0030, Accuracy: 539/1000 (53.90%)
#
# 5
#
# Test set: Average loss: 0.0029, Accuracy: 567/1000 (56.70%)
#
# 6
#
# Test set: Average loss: 0.0032, Accuracy: 511/1000 (51.10%)
#
# 7
#
# Test set: Average loss: 0.0053, Accuracy: 430/999 (43.04%)
#
# 8
#
# Test set: Average loss: 0.0031, Accuracy: 480/1000 (48.00%)
#
# 9
#
# Test set: Average loss: 0.0024, Accuracy: 679/1000 (67.90%)
#
# 10
#
# Test set: Average loss: 0.0031, Accuracy: 465/1000 (46.50%)
#
# 11
#
# Test set: Average loss: 0.0026, Accuracy: 633/1000 (63.30%)
#
# 12
#
# Test set: Average loss: 0.0023, Accuracy: 752/1000 (75.20%)
#
# 13
#
# Test set: Average loss: 0.0028, Accuracy: 611/1000 (61.10%)
#
# 14
#
# Test set: Average loss: 0.0023, Accuracy: 751/1000 (75.10%)
#
# 15
#
# Test set: Average loss: 0.0036, Accuracy: 647/1000 (64.70%)
#
# 16
#
# Test set: Average loss: 0.0020, Accuracy: 807/1000 (80.70%)
#
# 17
#
# Test set: Average loss: 0.0033, Accuracy: 521/1000 (52.10%)
#
# 18
#
# Test set: Average loss: 0.0038, Accuracy: 452/1000 (45.20%)
#
# 19
#
# Test set: Average loss: 0.0051, Accuracy: 365/999 (36.54%)
#
# 20
#
# Test set: Average loss: 0.0032, Accuracy: 496/1000 (49.60%)
#
# 21
#
# Test set: Average loss: 0.0088, Accuracy: 135/900 (15.00%)
#
# 22
#
# Test set: Average loss: 0.0047, Accuracy: 176/312 (56.41%)
#
# 23
#
# Test set: Average loss: 0.0037, Accuracy: 341/608 (56.09%)
#
# 24
#
# Test set: Average loss: 0.0037, Accuracy: 317/608 (52.14%)
#
# 25
#
# Test set: Average loss: 0.0026, Accuracy: 657/1000 (65.70%)
#
# 26
#
# Test set: Average loss: 0.0023, Accuracy: 716/1000 (71.60%)
#
# 27
#
# Test set: Average loss: 0.0034, Accuracy: 632/1000 (63.20%)
#
# 28
#
# Test set: Average loss: 0.0028, Accuracy: 569/1000 (56.90%)
#
# 29
#
# Test set: Average loss: 0.0032, Accuracy: 445/1000 (44.50%)
#
# 30
#
# Test set: Average loss: 0.0042, Accuracy: 453/999 (45.35%)
#
# 31
#
# Test set: Average loss: 0.0087, Accuracy: 201/1000 (20.10%)
#
# 32
#
# Test set: Average loss: 0.0026, Accuracy: 697/1000 (69.70%)
#
# 33
#
# Test set: Average loss: 0.0028, Accuracy: 645/1000 (64.50%)
#
# 34
#
# Test set: Average loss: 0.0028, Accuracy: 637/1000 (63.70%)
#
# 35
#
# Test set: Average loss: 0.0031, Accuracy: 638/1000 (63.80%)
#
# 36
#
# Test set: Average loss: 0.0024, Accuracy: 744/1000 (74.40%)
#
# 37
#
# Test set: Average loss: 0.0030, Accuracy: 574/1000 (57.40%)
#
# 38
#
# Test set: Average loss: 0.0030, Accuracy: 568/1000 (56.80%)
